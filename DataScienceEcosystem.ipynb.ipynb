# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ## Objectives
# 1. Understanding what data Science is
# 2. Learning about Popular Data Science tools
# 3. Exploring commonly used Data Science languages
# 4. Creating Markdown and Code cells in Jupyter Notebook

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# ## Data Science tools

# %% [markdown]
# 1.Jupyter Notebook
# 2. Rstudio
# 3. Anaconda

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ### PHANI VARMA
